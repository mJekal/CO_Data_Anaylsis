# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import os
import warnings
warnings.filterwarnings("ignore")
plt.style.use('ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv("Gosan_Flask_CO2_del13C_2001-2011 - 복사본 (2).csv")

# %%
data["Time"] = pd.to_datetime(data["Time"])

# %%
data
# Out:
#                    Time  13C [permil]     CO2
# 0   2001-01-03 12:44:00        -8.310  376.06
# 1   2001-01-10 12:52:00        -8.230  374.52
# 2   2001-01-10 12:53:00        -8.240  374.49
# 3   2001-01-17 12:47:00        -8.380  377.49
# 4   2001-01-17 12:48:00        -8.380  377.37
# ..                  ...           ...     ...
# 414 2011-10-27 12:36:00        -8.809  402.95
# 415 2011-11-29 12:56:00        -8.669  401.82
# 416 2012-01-12 12:01:00        -8.500  396.51
# 417 2012-01-19 13:19:00        -9.048  410.01
# 418 2012-02-11 12:30:00        -8.613  398.77
#
# [419 rows x 3 columns]

# %%
plt.figure(figsize=(18,10))
plt.plot(data["Time"], data["CO2"])
plt.xlabel("TIme")
plt.ylabel("CO2 [ppm]")
plt.show()

# %%
timeSeries = data[["Time","CO2"]]
timeSeries.index = timeSeries.Time
ts = timeSeries.drop("Time",axis=1)

# %%
ts
# Out:
#                         CO2
# Time
# 2001-01-03 12:44:00  376.06
# 2001-01-10 12:52:00  374.52
# 2001-01-10 12:53:00  374.49
# 2001-01-17 12:47:00  377.49
# 2001-01-17 12:48:00  377.37
# ...                     ...
# 2011-10-27 12:36:00  402.95
# 2011-11-29 12:56:00  401.82
# 2012-01-12 12:01:00  396.51
# 2012-01-19 13:19:00  410.01
# 2012-02-11 12:30:00  398.77
#
# [419 rows x 1 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(ts["CO2"], model="additive", period=7)
fig = plt.figure()
fig = result.plot()
fig.set_size_inches(20,15)

# %%
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts, lags=20, ax=ax1)

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(ts)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.458976
# p-value: 0.125777
# Critical Values:
# 	1%: -3.446
# 	5%: -2.869
# 	10%: -2.571

# %%
ts_diff = ts - ts.shift()
plt.figure(figsize=(22,8))
plt.plot(ts_diff)
plt.show()

# %%
result = adfuller(ts_diff[1:])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -11.614394
# p-value: 0.000000
# Critical Values:
# 	1%: -3.446
# 	5%: -2.869
# 	10%: -2.571

# %%
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts_diff[1:], lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ts_diff[1:], lags=20, ax=ax2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
ts = ts.asfreq('D')  # Set the frequency of the time series to daily

model = ARIMA(ts, order=(2, 1, 0))
try:
    model_fit = model.fit()
except ConvergenceWarning as e:
    print("Warning: Maximum Likelihood optimization failed to converge.")
    print("Trying an alternative parameter estimation method (css-mle).")
    model_fit = model.fit(method_kwargs={"method": "css-mle"})

if hasattr(model_fit, "mle_retvals"):
    print("MLE Optimization Results:")
    for key, value in model_fit.mle_retvals.items():
        print(f"\t{key}: {value}")
# Out:
# C:\Users\jegalmin\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# MLE Optimization Results:
# 	fopt: nan
# 	gopt: [nan nan nan]
# 	fcalls: 88
# 	warnflag: 2
# 	converged: False
# 	iterations: 0

# %%
start_index = pd.to_datetime("2002-09-06 17:39")
end_index = pd.to_datetime("2012-02-11 12:30")
forecast = model_fit.predict(start=start_index, end=end_index, typ='levels')

plt.figure(figsize=(22,8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1031333940000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
plt.figure(figsize=(22,8))
plt.plot(data["Time"], data["CO2"], label="original" )
plt.plot(forecast, label = "predicted")
plt.title("Time Series Forecast")
plt.legend()
plt.show()

# %%
resi = np.array(data[data["Time"] >= start_index]["CO2"]) - np.array(forecast)

# %%
plt.figure(figsize=(22,8))
plt.plot(data.Time[data.Time >= start_index], resi)
plt.xlabel("Time")
plt.ylabel("CO2")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resi, lags=20, ax=ax1)

# %%
result = adfuller(resi)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.756270
# p-value: 0.000000
# Critical Values:
# 	1%: -3.453
# 	5%: -2.872
# 	10%: -2.572

# %%
from sklearn import metrics

# %%
def scoring(y_true, y_pred):
    r2 = round(metrics.r2_score(y_true, y_pred) * 100, 3)
    corr = round(np.corrcoef(y_true, y_pred)[0,1],3)
    mape = round(
        metrics.mean_absolute_percentage_error(y_true, y_pred) * 100, 3)
    rmse = round(metrics.mean_squared_error(y_true, y_pred, squared=False),3)
    
    df = pd.DataFrame({
        'R2': r2,
        'Corr': corr,
        'PMSE': rmse,
        'MAPE': mape
    },
        index=[0])
    return df

# %%
scoring(np.array(data[data["Time"] >= start_index]["CO2"]), np.array(forecast))
# Out:
#        R2  Corr   PMSE   MAPE
# 0  48.818  0.72  6.607  1.109
